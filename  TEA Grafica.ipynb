# %%
import pandas as pd

# %%
import matplotlib.pyplot as plt

# %%
import seaborn as sns

# %%
data = pd.read_csv("TEA-Data.csv")
data
# Out:
#        Day  A_of_Units_Produced  Time_Hours  Throughput  Cost_of_Goods_Sold  \
# 0    Day_1                700.0          24        29.2                10.5
# 1    Day_2                900.0          24        37.5                13.5
# 2    Day_3                  1.0          24        41.7                15.0
# 3    Day_4                600.0          24        25.0                 9.0
# 4    Day_5                800.0          24        33.3                12.0
# 5    Day_6                  1.2          24        50.0                18.0
# 6    Day_7                  1.1          24        45.8                16.5
# 7    Day_8                900.0          24        37.5                13.5
# 8    Day_9                  1.2          24        50.0                18.0
# 9   Day_10                700.0          24        29.2                10.5
# 10  Day_11                800.0          24        33.3                12.0
# ...

# %%
fig, ax = plt.subplots(figsize=(10,5)) 
sns.heatmap(data.groupby(['Day','Time_Hours'])['Cost_of_Goods_Sold'].sum()
              .unstack('Time_Hours',fill_value=0), annot=True, fmt='g', cmap='Greens')
# Out:
# <AxesSubplot:xlabel='Time_Hours', ylabel='Day'>

# %%
fig, ax = plt.subplots(figsize=(10,5))
plt.plot(data.Day, data.Units_Produced2)
plt.show()

# %%
fig, ax = plt.subplots(figsize=(10,5))
plt.plot(data.Day, data.Units_Produced)
plt.show()

# %%
fig, ax = plt.subplots(figsize=(10,5))
plt.plot(data.Day, data.A_of_Units_Produced)
plt.show()

# %%
fig, ax = plt.subplots(figsize=(10,5))
plt.plot(data.Day, data.Time_Hours)
plt.show()

# %%
# fig, ax = plt.subplots(figsize=(10,5))
plt.plot(data.Day, data.Throughput)
plt.show()

# %%
# import pandas, matplotlib and seaborn
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
# choose style for plots
sns.set_style(“darkgrid”)
# import data
def = pd.read_csv('TEA-DATA.csv')
# define figure and axes for subplots
fig, ax = plt.subplots(figsize=(10,5), nrows=1, ncols=3).
plt.show()
# Out:
#   File "C:\Users\oscar.sanchez\AppData\Local\Temp\ipykernel_15148\3622438709.py", line 6
#     sns.set_style(“darkgrid”)
#                   ^
# SyntaxError: invalid character '“' (U+201C)

# %%
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_15148\3794928070.py in <module>
#       8           "A_of_Units_Produced"]
#       9
# ---> 10 data = [float(x.split()[0]) for x in Total]
#      11 plt.show()
#
# ~\AppData\Local\Temp\ipykernel_15148\3794928070.py in <listcomp>(.0)
#       8           "A_of_Units_Produced"]
#       9
# ---> 10 data = [float(x.split()[0]) for x in Total]
#      11 plt.show()
#
# ValueError: could not convert string to float: 'Throughput'

# %%
# Out:
#   File "C:\Users\oscar.sanchez\AppData\Local\Temp\ipykernel_15148\1745197371.py", line 2
#     Using matplotlib backend: TkAgg
#           ^
# SyntaxError: invalid syntax
